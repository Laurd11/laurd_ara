# %%
import numpy as np
import cv2
# from moviepy.editor import VideoFileClip
from IPython.display import clear_output, Image, display, HTML
import matplotlib.pyplot as plt
import pysindy as ps

# %% [markdown]
# ### Load U,V

# %%
u_all = np.load("C:/Users/laure/Documents/ARA/laurd_ara/video_processing/improved_fixed_low_piv_U.npy")
v_all = np.load("C:/Users/laure/Documents/ARA/laurd_ara/video_processing/improved_fixed_low_piv_V.npy")
t=np.arange(u_all.shape[0])
x= np.arange(u_all.shape[2])
y = np.arange(u_all.shape[1])
X, Y = np.meshgrid(x, y)

x_all = np.tile(X.reshape((1,X.shape[0],X.shape[1])),(t.shape[0],1,1))
y_all = np.tile(Y.reshape((1,X.shape[0],X.shape[1])),(t.shape[0],1,1))

all_data = np.stack((u_all,v_all,x_all,y_all))
# all_data = np.where(np.isfinite(all_data),all_data,0.)
# all_data.shape
all_data= all_data.transpose((2,3,1,0))
print(all_data.shape)
# Out:
# (17, 13, 161, 4)

# %%
# u[:, :, :, 0] = u_sol
# u[:, :, :, 1] = v_sol
u_dot = ps.FiniteDifference(axis=2)._differentiate(all_data[:,:,:,0], t=1)
v_dot = ps.FiniteDifference(axis=2)._differentiate(all_data[:,:,:,1], t=1)
x_dot = np.zeros(all_data[:,:,:,0].shape)
y_dot = np.zeros(all_data[:,:,:,0].shape)

data_dot= np.stack((u_dot,v_dot,x_dot,y_dot)).transpose((2,3,1,0))



# Choose 60 % of data for training because data is big...
# can only randomly subsample if you are passing u_dot to model.fit!!!
# train = np.random.choice(len(t), int(len(t) * 0.6), replace=False)
# test = [i for i in np.arange(len(t)) if i not in train]
# u_train = u[:, :, :, :]
# u_test = u[:, :, test, :]
# u_dot_train = u_dot[:, :, :, :]
# u_dot_test = u_dot[:, :, test, :]
# t_train = t#[train]
# t_test = t[test]

spatial_grid = np.asarray([X, Y]).T

# %%
library_functions = [
    lambda x: x,
    lambda x: x*x,
    lambda x: x * x * x,
    lambda x,y: x*y,
    lambda x, y: x * y * y,
    lambda x, y: x * x * y,
]
library_function_names = [
    lambda x: x,
    lambda x: x + x,
    lambda x: x + x + x,
    lambda x,y: x+y,
    lambda x, y: x + y + y,
    lambda x, y: x + x + y,
]
pde_lib = ps.PDELibrary(
    library_functions=library_functions,
    function_names=library_function_names,
    derivative_order=2,
    spatial_grid=spatial_grid,
    include_bias=True,
    is_uniform=True,
    #periodic=True
)

# %%
spatial_grid.shape
# Out:
# (13, 17, 2)

# %%
# poly_library = ps.PolynomialLibrary(include_bias=False)
# fourier_library = ps.FourierLibrary()

# # inputs_per_library = np.array([[0,1],[0,1],[0,0]])
# tensor_array = [[1, 0]]

# %%
# generalized_library = ps.GeneralizedLibrary(
#     [fourier_library, pde_lib],
#     tensor_array=tensor_array,
#     # inputs_per_library=inputs_per_library,
# )
# #
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3984\4165749547.py in <module>
# ----> 1 generalized_library = ps.GeneralizedLibrary(
#       2     [fourier_library, pde_lib],
#       3     tensor_array=tensor_array,
#       4     # inputs_per_library=inputs_per_library,
#       5 )
#
# ~\anaconda3\lib\site-packages\pysindy\feature_library\generalized_library.py in __init__(self, libraries, tensor_array, inputs_per_library, library_ensemble, ensemble_indices)
#     170             for i in range(len(tensor_array)):
#     171                 if np.sum(tensor_array[i]) < 2:
# --> 172                     raise ValueError(
#     173                         "If specifying libraries to tensor together, must "
#     174                         "specify at least two libraries (there should be at "
#
# ValueError: If specifying libraries to tensor together, must specify at least two libraries (there should be at least two entries with value 1 in the tensor_array).

# %%
thresh=6e-3
print('STLSQ model: ')
optimizer = ps.STLSQ(threshold=thresh, alpha=1e-3,max_iter=1000)

model = ps.SINDy(feature_library=pde_lib, optimizer=optimizer)
model.fit(all_data, x_dot=data_dot,ensemble=True)
# u_dot_stlsq = model.predict(u_test)
# Out:
# STLSQ model:
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\pysindy.py:305: UserWarning: Ensembling arguments are deprecated.Use the EnsembleOptimizer class instead.
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\base.py:289: UserWarning: n_models must be a positive integer.  Explicitly initialized to zero or None, defaulting to 20.
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# C:\Users\laure\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:193: UserWarning: Sparsity parameter is too big (0.006) and eliminated all coefficients
#   warnings.warn(
# SINDy(differentiation_method=FiniteDifference(axis=-2),
#       feature_library=<pysindy.feature_library.pde_library.PDELibrary object at 0x000001FAC89E1820>,
#       feature_names=['x0', 'x1', 'x2', 'x3'],
#       optimizer=STLSQ(alpha=0.001, max_iter=1000, threshold=0.006))

# %%
model.print()
# Out:
# (x0)' = -0.003 x1_1 + -0.001 x2x2x3_1
# (x1)' = 0.000
# (x2)' = 0.000
# (x3)' = 0.000
